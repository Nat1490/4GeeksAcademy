# %% [markdown]
# <a href="https://colab.research.google.com/github/Nat1490/4GeeksAcademy/blob/master/Copia_de_AutoGen_Estudio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U autogenstudio
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.4/325.4 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 16.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
# !ngrok config add-authtoken 2Lp8eoqxs3ZKpqBFIselZvJIzlc_2ymsmJ24R5RjuZJ1LVhCv
print("Token de autenticación establecido correctamente.")
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Token de autenticación establecido correctamente.

# %%
import os
os.environ["OPENAI_API_KEY"]="2Lp8eoqxs3ZKpqBFIselZvJIzlc_2ymsmJ24R5RjuZJ1LVhCv"

# %%
get_ipython().system_raw('autogenstudio ui --port 8001')

# Paso 3: Establecer el túnel ngrok
from pyngrok import ngrok
public_url = ngrok.connect(8000)
print('Public URL:', public_url)
# Out:
# KeyboardInterrupt
# Public URL: NgrokTunnel: "https://4bf4-35-229-44-182.ngrok-free.app" -> "http://localhost:8000"
